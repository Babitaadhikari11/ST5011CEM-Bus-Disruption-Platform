# %%
# import tools for selecting the correct python executable
import os
import sys

# use the same python executable for spark driver and workers
python_path = sys.executable

os.environ["PYSPARK_PYTHON"] = python_path
os.environ["PYSPARK_DRIVER_PYTHON"] = python_path

# import sparksession
from pyspark.sql import SparkSession

# create or reuse the spark session
spark = (
    SparkSession.builder
    .appName("dataset_joining")
    .config("spark.sql.shuffle.partitions", "4")
    .config("spark.sql.session.timeZone", "Europe/London")
    .config(
        "spark.pyspark.python",
        python_path
    )
    .config(
        "spark.pyspark.driver.python",
        python_path
        )
    .config(
        "spark.executorEnv.PYSPARK_PYTHON",
        python_path
    )
    .getOrCreate()
)

# make sure timetable and live times use uk local time
spark.conf.set(
    "spark.sql.session.timeZone",
    "Europe/London"
)

# reduce unnecessary spark messages
spark.sparkContext.setLogLevel("WARN")

print("python version:", sys.version.split()[0])
print("python path:", python_path)
print("pyspark version:", spark.version)
print(
    "shuffle partitions:",
    spark.conf.get("spark.sql.shuffle.partitions")
)
print(
    "session time zone:",
    spark.conf.get("spark.sql.session.timeZone")
)
print("spark ui:", spark.sparkContext.uiWebUrl)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/14 22:18:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/07/14 22:18:19 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/07/14 22:18:19 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# python version: 3.11.15
# python path: /opt/anaconda3/envs/pyspark35/bin/python
# pyspark version: 3.5.1
# shuffle partitions: 4
# session time zone: Europe/London
# spark ui: http://192.168.1.8:4042

# %%
from pathlib import Path
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# %%
#  folder where the notebook is running
current_folder = Path.cwd()
if current_folder.name == "notebooks":
    project_root = current_folder.parent
else:
    project_root = current_folder
timetable_path = (
    project_root
    / "data"
    / "processed"
    / "timetable"
)
vehicle_path = (
    project_root
    / "data"
    / "processed"
    / "vehicle_locations"
)
joined_path = (
    project_root
    / "data"
    / "processed"
    / "joined_transport_data"
)
print("project root:", project_root)
print("timetable path:", timetable_path)
print("timetable path exists:", timetable_path.exists())
print("vehicle path:", vehicle_path)
print("vehicle path exists:", vehicle_path.exists())
print("joined output path:", joined_path)
# Out:
# project root: /Users/babitaadhikari/Desktop/bus-disruption-platform
# timetable path: /Users/babitaadhikari/Desktop/bus-disruption-platform/data/processed/timetable
# timetable path exists: True
# vehicle path: /Users/babitaadhikari/Desktop/bus-disruption-platform/data/processed/vehicle_locations
# vehicle path exists: True
# joined output path: /Users/babitaadhikari/Desktop/bus-disruption-platform/data/processed/joined_transport_data

# %% [markdown]
# ## Load dataset

# %%
# load the processed timetable dataset
timetable_df = spark.read.parquet(
    str(timetable_path)
)
# load the processed vehicle location dataset
vehicle_df = spark.read.parquet(
    str(vehicle_path)
)
print(
    "timetable rows:",
    f"{timetable_df.count():,}"
)
print(
    "vehicle observations:",
    f"{vehicle_df.count():,}"
)
print(
    "timetable partitions:",
    timetable_df.rdd.getNumPartitions()
)
print(
    "vehicle partitions:",
    vehicle_df.rdd.getNumPartitions()
)
# Out:
# timetable rows: 5,370,199
# vehicle observations: 9,546
# timetable partitions: 8
# vehicle partitions: 4

# %%
# display all timetable column names
print("timetable columns")
for column_name in timetable_df.columns:
    print(column_name)
# display all vehicle location column names
print("\nvehicle location columns")
for column_name in vehicle_df.columns:
    print(column_name)
# Out:
# timetable columns
# agency_id
# agency_name
# agency_noc
# route_id
# route_short_name
# route_long_name
# service_id
# trip_id
# vehicle_journey_code
# trip_headsign
# direction_id
# stop_id
# stop_code
# stop_name
# stop_sequence
# arrival_time
# departure_time
# arrival_seconds
# departure_seconds
# stop_lat
# stop_lon
# shape_id
#
# vehicle location columns
# source_file
# snapshot_time
# recorded_at_time
# valid_until_time
# operator_ref
# line_ref
# published_line_name
# direction_ref
# dated_vehicle_journey_ref
# journey_pattern_ref
# vehicle_ref
# block_ref
# origin_ref
# destination_ref
# destination_name
# origin_aimed_departure_time
# longitude
# latitude
# bearing
# observation_date
# observation_hour
# observation_day_of_week
# observation_age_seconds

# %%
# display the timetable schema
print("timetable schema")
timetable_df.printSchema()
# display the vehicle location schema
print("vehicle location schema")
vehicle_df.printSchema()
# Out:
# timetable schema
# root
#  |-- agency_id: string (nullable = true)
#  |-- agency_name: string (nullable = true)
#  |-- agency_noc: string (nullable = true)
#  |-- route_id: string (nullable = true)
#  |-- route_short_name: string (nullable = true)
#  |-- route_long_name: string (nullable = true)
#  |-- service_id: string (nullable = true)
#  |-- trip_id: string (nullable = true)
#  |-- vehicle_journey_code: string (nullable = true)
#  |-- trip_headsign: string (nullable = true)
#  |-- direction_id: string (nullable = true)
#  |-- stop_id: string (nullable = true)
#  |-- stop_code: string (nullable = true)
#  |-- stop_name: string (nullable = true)
#  |-- stop_sequence: integer (nullable = true)
#  |-- arrival_time: string (nullable = true)
#  |-- departure_time: string (nullable = true)
#  |-- arrival_seconds: integer (nullable = true)
#  |-- departure_seconds: integer (nullable = true)
#  |-- stop_lat: double (nullable = true)
#  |-- stop_lon: double (nullable = true)
#  |-- shape_id: string (nullable = true)
#
# vehicle location schema
# root
#  |-- source_file: string (nullable = true)
#  |-- snapshot_time: timestamp (nullable = true)
#  |-- recorded_at_time: timestamp (nullable = true)
#  |-- valid_until_time: timestamp (nullable = true)
#  |-- operator_ref: string (nullable = true)
#  |-- line_ref: string (nullable = true)
#  |-- published_line_name: string (nullable = true)
#  |-- direction_ref: string (nullable = true)
#  |-- dated_vehicle_journey_ref: string (nullable = true)
#  |-- journey_pattern_ref: string (nullable = true)
#  |-- vehicle_ref: string (nullable = true)
#  |-- block_ref: string (nullable = true)
#  |-- origin_ref: string (nullable = true)
#  |-- destination_ref: string (nullable = true)
#  |-- destination_name: string (nullable = true)
#  |-- origin_aimed_departure_time: timestamp (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- bearing: double (nullable = true)
#  |-- observation_date: date (nullable = true)
#  |-- observation_hour: integer (nullable = true)
#  |-- observation_day_of_week: integer (nullable = true)
#  |-- observation_age_seconds: long (nullable = true)

# %%
# define timetable columns required for joining
required_timetable_columns = [
    "agency_noc",
    "route_id",
    "route_short_name",
    "trip_id",
    "vehicle_journey_code",
    "direction_id",
    "stop_id",
    "stop_name",
    "stop_sequence",
    "arrival_seconds",
    "departure_seconds"
]
# define vehicle columns required for joining
required_vehicle_columns = [
    "source_file",
    "recorded_at_time",
    "operator_ref",
    "line_ref",
    "dated_vehicle_journey_ref",
    "direction_ref",
    "vehicle_ref",
    "origin_aimed_departure_time"
]
# find missing timetable columns
missing_timetable_columns = [
    column_name
    for column_name in required_timetable_columns
    if column_name not in timetable_df.columns
]
# find missing vehicle columns
missing_vehicle_columns = [
    column_name
    for column_name in required_vehicle_columns
    if column_name not in vehicle_df.columns
]
print(
    "missing timetable columns:",
    missing_timetable_columns
)
print(
    "missing vehicle columns:",
    missing_vehicle_columns
)
if missing_timetable_columns:
    raise ValueError(
        f"missing timetable columns {missing_timetable_columns}"
    )
if missing_vehicle_columns:
    raise ValueError(
        f"missing vehicle columns {missing_vehicle_columns}"
    )
print("all required joining columns are available")
# Out:
# missing timetable columns: []
# missing vehicle columns: []
# all required joining columns are available

# %%
# display sample timetable identifiers
print("timetable joining values")
timetable_df.select(
    "agency_noc",
    "route_short_name",
    "vehicle_journey_code",
    "direction_id"
).where(
    F.col("vehicle_journey_code").isNotNull()
).dropDuplicates().show(
    20,
    truncate=False
)
# display sample vehicle location identifiers
print("vehicle location joining values")
vehicle_df.select(
    "operator_ref",
    "line_ref",
    "dated_vehicle_journey_ref",
    "direction_ref"
).where(
    F.col("dated_vehicle_journey_ref").isNotNull()
).dropDuplicates().show(
    20,
    truncate=False
)
# Out:
# timetable joining values
# +----------+----------------+--------------------+------------+
# |agency_noc|route_short_name|vehicle_journey_code|direction_id|
# +----------+----------------+--------------------+------------+
# |TNXB      |35              |VJ225               |1           |
# |TNXB      |997             |VJ22                |0           |
# |DIAM      |21              |vj_11               |1           |
# |TNXB      |4               |VJ297               |0           |
# |TNXB      |94              |VJ176               |1           |
# |NATX      |100             |VJ20                |1           |
# |DIAM      |12A             |vj_7                |0           |
# |TNXB      |X8              |VJ49                |0           |
# |TNXB      |X4              |VJ377               |1           |
# |SCGL      |33              |VJ23                |0           |
# |TNXB      |79              |VJ316               |1           |
# |TNXB      |X4              |VJ48                |1           |
# |TNXB      |32              |VJ84                |0           |
# |TNXB      |998             |VJ296               |0           |
# |TNXB      |6A              |VJ278               |1           |
# |AMNO      |8               |vj_1                |0           |
# |TNXB      |94              |VJ108               |0           |
# |TBTN      |X38             |VJ232               |1           |
# |TCVW      |21              |VJ248               |0           |
# |TNXB      |4M              |VJ129               |0           |
# +----------+----------------+--------------------+------------+
# only showing top 20 rows
#
# vehicle location joining values
# +------------+--------+-------------------------+-------------+
# |operator_ref|line_ref|dated_vehicle_journey_ref|direction_ref|
# +------------+--------+-------------------------+-------------+
# |TCVW        |6A      |133                      |outbound     |
# |TCVW        |X1      |65                       |outbound     |
# |TCVW        |13      |107                      |outbound     |
# |TCVW        |X1      |77                       |outbound     |
# |TCVW        |11      |72                       |inbound      |
# |TCVW        |X1      |67                       |outbound     |
# |TCVW        |6       |120                      |inbound      |
# |TCVW        |6       |137                      |outbound     |
# |TCVW        |6       |138                      |inbound      |
# |TCVW        |9       |81                       |outbound     |
# |TCVW        |X1      |69                       |outbound     |
# |TCVW        |9       |75                       |outbound     |
# |TCVW        |7       |97                       |outbound     |
# |TCVW        |6A      |136                      |inbound      |
# |TCVW        |6A      |126                      |inbound      |
# |TCVW        |15      |93                       |outbound     |
# |TCVW        |6A      |152                      |inbound      |
# |TCVW        |11      |67                       |outbound     |
# |TNXB        |8C      |75                       |outbound     |
# |TNXB        |8A      |83                       |inbound      |
# +------------+--------+-------------------------+-------------+
# only showing top 20 rows

# %%
# group stop level timetable records into one row for each trip
trip_level_df = (
    timetable_df
    .groupBy(
        "agency_noc",
        "route_id",
        "route_short_name",
        "service_id",
        "trip_id",
        "vehicle_journey_code",
        "trip_headsign",
        "direction_id"
    )
    .agg(
        F.min(
            "departure_seconds"
        ).alias(
            "scheduled_start_seconds"
        ),

        F.max(
            "arrival_seconds"
        ).alias(
            "scheduled_end_seconds"
        ),

        F.min(
            "stop_sequence"
        ).alias(
            "first_stop_sequence"
        ),

        F.max(
            "stop_sequence"
        ).alias(
            "last_stop_sequence"
        ),

        F.countDistinct(
            "stop_id"
        ).alias(
            "scheduled_stop_count"
        )
    )
)
print(
    "trip level timetable rows:",
    f"{trip_level_df.count():,}"
)
trip_level_df.show(
    10,
    truncate=False
)
# Out:
# trip level timetable rows: 135,003
# 26/07/14 22:18:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:18:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:18:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:18:58 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:00 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:00 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:00 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:00 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:01 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:02 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:03 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:03 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:08 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:08 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:08 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:08 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:08 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:08 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:08 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:08 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:09 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:10 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# +----------+--------+----------------+----------+------------------------------------------+--------------------+------------------------------+------------+-----------------------+---------------------+-------------------+------------------+--------------------+
# |agency_noc|route_id|route_short_name|service_id|trip_id                                   |vehicle_journey_code|trip_headsign                 |direction_id|scheduled_start_seconds|scheduled_end_seconds|first_stop_sequence|last_stop_sequence|scheduled_stop_count|
# +----------+--------+----------------+----------+------------------------------------------+--------------------+------------------------------+------------+-----------------------+---------------------+-------------------+------------------+--------------------+
# |TNXB      |1719805 |997             |620       |VJ006ad9cca356b4b9020bb8f1d151560e105c5585|VJ22                |Walsall Bus Station           |0           |38880                  |42780                |0                  |65                |66                  |
# |TNXB      |13102   |71              |99        |VJ0090dc889b9ff17f88961c99915d303f93e1e47f|VJ9                 |Chelmsley Interchange         |0           |45960                  |49020                |0                  |53                |54                  |
# |SCGL      |132049  |33              |99        |VJ0092575ef45ac56c24180732e218f69369ff87aa|VJ26                |Ross-on-Wye Cantilupe Road (1)|1           |52080                  |55800                |0                  |42                |43                  |
# |AMNO      |39051   |64              |372       |VJ00a995dcb3cb013d2d63e9d792b031b56fcb97ea|vj_13               |Bus Station                   |0           |51600                  |55140                |0                  |44                |45                  |
# |TNXB      |632     |X8              |1909      |VJ01406b2980d64dfcb633c6f080312b2f404ba894|VJ49                |Wolverhampton Bus Station     |0           |36120                  |41340                |0                  |64                |65                  |
# |TNXB      |603     |4M              |99        |VJ014e013ce4ce872849e3f937167ea22ddc4fcc92|VJ145               |Saddlers Centre               |1           |40800                  |45480                |0                  |64                |65                  |
# |TNXB      |128606  |35              |7725      |VJ0154f5536a162011cf3be223e489ba825357c363|VJ345               |Moor St Selfridges            |1           |65580                  |68100                |0                  |51                |52                  |
# |TNXB      |6565    |X4              |6606      |VJ01642b0895e8bbbfc61c98aedd068c0f9edb81ee|VJ377               |The Square Peg                |1           |35280                  |38100                |0                  |44                |45                  |
# |SCNH      |132642  |60              |467       |VJ017431489ae647fe8ed3ba469c052f53f7e6280d|VJ30                |Kirby Corner Interchange      |0           |35400                  |40080                |0                  |84                |85                  |
# |AMNO      |117569  |2               |1904      |VJ017705dc7c3054514e895d51c4e520da700db411|vj_1                |No 19                         |0           |32400                  |32940                |0                  |11                |12                  |
# +----------+--------+----------------+----------+------------------------------------------+--------------------+------------------------------+------------+-----------------------+---------------------+-------------------+------------------+--------------------+
# only showing top 10 rows

# %%
# create a function that removes spaces and special characters
def compact_key(column_name):
    return F.upper(
        F.regexp_replace(
            F.trim(
                F.col(column_name)
            ),
            r"[^A-Za-z0-9]",
            ""
        )
    )
# create a function that extracts the final part of a journey reference
def journey_tail_key(column_name):
    raw_value = F.upper(
        F.trim(
            F.col(column_name)
        )
    )

    tail_value = F.regexp_extract(
        raw_value,
        r"([^:/|]+)$",
        1
    )
    return F.regexp_replace(
        tail_value,
        r"[^A-Z0-9]",
        ""
    )
print("join key functions created")
# Out:
# join key functions created

# %%
# create cleaned timetable identifiers
trip_prepared_df = (
    trip_level_df

    .withColumn(
        "timetable_operator_key",
        compact_key("agency_noc")
    )

    .withColumn(
        "timetable_line_key",
        compact_key("route_short_name")
    )

    .withColumn(
        "timetable_journey_full_key",
        compact_key("vehicle_journey_code")
    )

    .withColumn(
        "timetable_journey_tail_key",
        journey_tail_key(
            "vehicle_journey_code"
        )
    )

    .withColumn(
        "timetable_direction_key",
        compact_key("direction_id")
    )

    .withColumn(
        "scheduled_clock_seconds",
        F.pmod(
            F.col("scheduled_start_seconds"),
            F.lit(86400)
        )
    )
)
# cache because these keys will be checked several times
trip_prepared_df.cache()

print(
    "prepared timetable trips:",
    f"{trip_prepared_df.count():,}"
)
# Out:
# 26/07/14 22:19:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:16 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:17 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:18 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:19 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:23 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:24 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# 26/07/14 22:19:25 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# [Stage 31:>                                                         (0 + 4) / 4]
# prepared timetable trips: 135,003

# %%
# create cleaned vehicle location identifiers
vehicle_prepared_df = (
    vehicle_df
    .withColumn(
        "vehicle_operator_key",
        compact_key("operator_ref")
    )

    .withColumn(
        "vehicle_line_ref_key",
        compact_key("line_ref")
    )

    .withColumn(
        "vehicle_published_line_key",
        compact_key("published_line_name")
    )

    .withColumn(
        "vehicle_journey_full_key",
        compact_key(
            "dated_vehicle_journey_ref"
        )
    )

    .withColumn(
        "vehicle_journey_tail_key",
        journey_tail_key(
            "dated_vehicle_journey_ref"
        )
    )

    .withColumn(
        "vehicle_direction_key",
        compact_key("direction_ref")
    )

    .withColumn(
        "aimed_start_seconds",
        F.hour(
            F.col(
                "origin_aimed_departure_time"
            )
        ) * 3600
        + F.minute(
            F.col(
                "origin_aimed_departure_time"
            )
        ) * 60
        + F.second(
            F.col(
                "origin_aimed_departure_time"
            )
        )
    )
)
# create one unique identifier for every live observation
vehicle_prepared_df = (
    vehicle_prepared_df
    .withColumn(
        "observation_id",
        F.sha2(
            F.concat_ws(
                "||",

                F.coalesce(
                    F.col("source_file"),
                    F.lit("")
                ),

                F.coalesce(
                    F.col("vehicle_ref"),
                    F.lit("")
                ),

                F.coalesce(
                    F.col(
                        "recorded_at_time"
                    ).cast("string"),
                    F.lit("")
                ),

                F.coalesce(
                    F.col("line_ref"),
                    F.lit("")
                )
            ),
            256
        )
    )
)
# cache because these keys will be reused
vehicle_prepared_df.cache()
print(
    "prepared vehicle observations:",
    f"{vehicle_prepared_df.count():,}"
)
# Out:
# 26/07/14 22:19:32 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 39:=============================>                            (2 + 2) / 4]
# prepared vehicle observations: 9,546

# %%
# display sample timetable join keys
print("prepared timetable keys")
trip_prepared_df.select(
    "agency_noc",
    "timetable_operator_key",
    "route_short_name",
    "timetable_line_key",
    "vehicle_journey_code",
    "timetable_journey_full_key",
    "timetable_journey_tail_key"
).where(
    F.col(
        "timetable_journey_full_key"
    ).isNotNull()
).dropDuplicates().show(
    20,
    truncate=False
)

# display sample vehicle join keys
print("prepared vehicle keys")

vehicle_prepared_df.select(
    "operator_ref",
    "vehicle_operator_key",
    "line_ref",
    "vehicle_line_ref_key",
    "published_line_name",
    "vehicle_published_line_key",
    "dated_vehicle_journey_ref",
    "vehicle_journey_full_key",
    "vehicle_journey_tail_key"
).where(
    F.col(
        "vehicle_journey_full_key"
    ).isNotNull()
).dropDuplicates().show(
    20,
    truncate=False
)
# Out:
# prepared timetable keys
# +----------+----------------------+----------------+------------------+--------------------+--------------------------+--------------------------+
# |agency_noc|timetable_operator_key|route_short_name|timetable_line_key|vehicle_journey_code|timetable_journey_full_key|timetable_journey_tail_key|
# +----------+----------------------+----------------+------------------+--------------------+--------------------------+--------------------------+
# |SCGL      |SCGL                  |33              |33                |VJ26                |VJ26                      |VJ26                      |
# |TNXB      |TNXB                  |X8              |X8                |VJ49                |VJ49                      |VJ49                      |
# |TNXB      |TNXB                  |X4              |X4                |VJ377               |VJ377                     |VJ377                     |
# |AMNO      |AMNO                  |2               |2                 |vj_1                |VJ1                       |VJ1                       |
# |AMNO      |AMNO                  |64              |64                |vj_6                |VJ6                       |VJ6                       |
# |TCVW      |TCVW                  |11              |11                |VJ185               |VJ185                     |VJ185                     |
# |TCVW      |TCVW                  |12X             |12X               |VJ132               |VJ132                     |VJ132                     |
# |AMNO      |AMNO                  |8               |8                 |vj_1                |VJ1                       |VJ1                       |
# |TNXB      |TNXB                  |32              |32                |VJ132               |VJ132                     |VJ132                     |
# |FPOT      |FPOT                  |22              |22                |VJ625               |VJ625                     |VJ625                     |
# |TCVW      |TCVW                  |21              |21                |VJ474               |VJ474                     |VJ474                     |
# |TNXB      |TNXB                  |10              |10                |VJ267               |VJ267                     |VJ267                     |
# |AMNO      |AMNO                  |24              |24                |vj_21               |VJ21                      |VJ21                      |
# |TNXB      |TNXB                  |45              |45                |VJ181               |VJ181                     |VJ181                     |
# |TNXB      |TNXB                  |10              |10                |VJ47                |VJ47                      |VJ47                      |
# |TNXB      |TNXB                  |97              |97                |VJ639               |VJ639                     |VJ639                     |
# |DIAM      |DIAM                  |27              |27                |vj_20               |VJ20                      |VJ20                      |
# |TNXB      |TNXB                  |X13             |X13               |VJ82                |VJ82                      |VJ82                      |
# |AMGR      |AMGR                  |212             |212               |3                   |3                         |3                         |
# |AMNO      |AMNO                  |99C             |99C               |vj_1                |VJ1                       |VJ1                       |
# +----------+----------------------+----------------+------------------+--------------------+--------------------------+--------------------------+
# only showing top 20 rows
#
# prepared vehicle keys
# +------------+--------------------+--------+--------------------+-------------------+--------------------------+-------------------------+------------------------+------------------------+
# |operator_ref|vehicle_operator_key|line_ref|vehicle_line_ref_key|published_line_name|vehicle_published_line_key|dated_vehicle_journey_ref|vehicle_journey_full_key|vehicle_journey_tail_key|
# +------------+--------------------+--------+--------------------+-------------------+--------------------------+-------------------------+------------------------+------------------------+
# |TCVW        |TCVW                |11      |11                  |11                 |11                        |72                       |72                      |72                      |
# |TCVW        |TCVW                |6       |6                   |6                  |6                         |137                      |137                     |137                     |
# |TCVW        |TCVW                |9       |9                   |9                  |9                         |79                       |79                      |79                      |
# |TCVW        |TCVW                |X1      |X1                  |X1                 |X1                        |71                       |71                      |71                      |
# |TCVW        |TCVW                |13      |13                  |13                 |13                        |111                      |111                     |111                     |
# |TCVW        |TCVW                |X1      |X1                  |X1                 |X1                        |69                       |69                      |69                      |
# |TCVW        |TCVW                |9       |9                   |9                  |9                         |75                       |75                      |75                      |
# |TCVW        |TCVW                |X1      |X1                  |X1                 |X1                        |80                       |80                      |80                      |
# |TCVW        |TCVW                |7       |7                   |7                  |7                         |97                       |97                      |97                      |
# |TCVW        |TCVW                |9       |9                   |9                  |9                         |76                       |76                      |76                      |
# |TCVW        |TCVW                |6A      |6A                  |6A                 |6A                        |126                      |126                     |126                     |
# |TCVW        |TCVW                |X1      |X1                  |X1                 |X1                        |84                       |84                      |84                      |
# |TCVW        |TCVW                |7       |7                   |7                  |7                         |100                      |100                     |100                     |
# |TCVW        |TCVW                |X1      |X1                  |X1                 |X1                        |55                       |55                      |55                      |
# |TNXB        |TNXB                |11      |11                  |11                 |11                        |802                      |802                     |802                     |
# |TNXB        |TNXB                |6       |6                   |6                  |6                         |563                      |563                     |563                     |
# |TNXB        |TNXB                |10      |10                  |10                 |10                        |549                      |549                     |549                     |
# |TNXB        |TNXB                |6       |6                   |6                  |6                         |586                      |586                     |586                     |
# |TNXB        |TNXB                |7       |7                   |7                  |7                         |551                      |551                     |551                     |
# |TNXB        |TNXB                |7       |7                   |7                  |7                         |547                      |547                     |547                     |
# +------------+--------------------+--------+--------------------+-------------------+--------------------------+-------------------------+------------------------+------------------------+
# only showing top 20 rows

# %%
# create a function that counts matching distinct values
def count_key_overlap(
    left_df,
    left_column,
    right_df,
    right_column
):
    left_keys = (
        left_df
        .select(
            F.col(left_column).alias(
                "join_key"
            )
        )
        .filter(
            F.col("join_key").isNotNull()
            & (F.col("join_key") != "")
        )
        .distinct()
    )

    right_keys = (
        right_df
        .select(
            F.col(right_column).alias(
                "join_key"
            )
        )
        .filter(
            F.col("join_key").isNotNull()
            & (F.col("join_key") != "")
        )
        .distinct()
    )

    overlap_count = (
        left_keys
        .join(
            right_keys,
            on="join_key",
            how="inner"
        )
        .count()
    )

    return overlap_count
print("key overlap function created")
# Out:
# key overlap function created

# %%
# compare timetable routes with vehicle line references
line_ref_overlap = count_key_overlap(
    trip_prepared_df,
    "timetable_line_key",
    vehicle_prepared_df,
    "vehicle_line_ref_key"
)
# compare timetable routes with published line names
published_line_overlap = count_key_overlap(
    trip_prepared_df,
    "timetable_line_key",
    vehicle_prepared_df,
    "vehicle_published_line_key"
)
# compare complete journey references
full_journey_overlap = count_key_overlap(
    trip_prepared_df,
    "timetable_journey_full_key",
    vehicle_prepared_df,
    "vehicle_journey_full_key"
)
# compare final parts of journey references
tail_journey_overlap = count_key_overlap(
    trip_prepared_df,
    "timetable_journey_tail_key",
    vehicle_prepared_df,
    "vehicle_journey_tail_key"
)
# compare operator references
operator_overlap = count_key_overlap(
    trip_prepared_df,
    "timetable_operator_key",
    vehicle_prepared_df,
    "vehicle_operator_key"
)
print(
    "line ref overlap:",
    line_ref_overlap
)
print(
    "published line overlap:",
    published_line_overlap
)
print(
    "full journey overlap:",
    full_journey_overlap
)
print(
    "tail journey overlap:",
    tail_journey_overlap
)

print(
    "operator overlap:",
    operator_overlap
)
# Out:
# line ref overlap: 137
# published line overlap: 137
# full journey overlap: 85
# tail journey overlap: 85
# operator overlap: 2

# %%
# choose the vehicle route column with the most overlap
if line_ref_overlap >= published_line_overlap:
    selected_vehicle_line_column = (
        "vehicle_line_ref_key"
    )

    selected_line_method = "line ref"

else:
    selected_vehicle_line_column = (
        "vehicle_published_line_key"
    )

    selected_line_method = (
        "published line name"
    )
# choose the journey column with the most overlap
if full_journey_overlap >= tail_journey_overlap:
    selected_timetable_journey_column = (
        "timetable_journey_full_key"
    )

    selected_vehicle_journey_column = (
        "vehicle_journey_full_key"
    )

    selected_journey_method = (
        "full journey reference"
    )

else:
    selected_timetable_journey_column = (
        "timetable_journey_tail_key"
    )

    selected_vehicle_journey_column = (
        "vehicle_journey_tail_key"
    )

    selected_journey_method = (
        "journey reference tail"
    )


print(
    "selected line method:",
    selected_line_method
)

print(
    "selected vehicle line column:",
    selected_vehicle_line_column
)

print(
    "selected journey method:",
    selected_journey_method
)

print(
    "selected timetable journey column:",
    selected_timetable_journey_column
)

print(
    "selected vehicle journey column:",
    selected_vehicle_journey_column
)
# Out:
# selected line method: line ref
# selected vehicle line column: vehicle_line_ref_key
# selected journey method: full journey reference
# selected timetable journey column: timetable_journey_full_key
# selected vehicle journey column: vehicle_journey_full_key

# %%
# create aliases for clear join references
vehicle_alias = vehicle_prepared_df.alias("v")

timetable_alias = trip_prepared_df.alias("t")


# define the vehicle journey key
vehicle_journey_value = F.col(
    f"v.{selected_vehicle_journey_column}"
)

# define the timetable journey key
timetable_journey_value = F.col(
    f"t.{selected_timetable_journey_column}"
)

# define the vehicle line key
vehicle_line_value = F.col(
    f"v.{selected_vehicle_line_column}"
)

# define the timetable line key
timetable_line_value = F.col(
    "t.timetable_line_key"
)


# match records using route and journey references
join_condition = (
    vehicle_journey_value.isNotNull()
    & timetable_journey_value.isNotNull()
    & (vehicle_journey_value != "")
    & (timetable_journey_value != "")
    & (
        vehicle_journey_value
        == timetable_journey_value
    )
    & (
        vehicle_line_value
        == timetable_line_value
    )
)


# keep every vehicle observation using a left join
candidate_matches_df = (
    vehicle_alias
    .join(
        timetable_alias,
        on=join_condition,
        how="left"
    )
    .select(
        "v.*",

        F.col("t.trip_id").alias(
            "matched_trip_id"
        ),

        F.col("t.service_id").alias(
            "matched_service_id"
        ),

        F.col("t.route_id").alias(
            "matched_route_id"
        ),

        F.col("t.route_short_name").alias(
            "matched_route_short_name"
        ),

        F.col("t.vehicle_journey_code").alias(
            "matched_vehicle_journey_code"
        ),

        F.col("t.direction_id").alias(
            "matched_direction_id"
        ),

        F.col("t.trip_headsign").alias(
            "matched_trip_headsign"
        ),

        F.col("t.scheduled_start_seconds").alias(
            "scheduled_start_seconds"
        ),

        F.col("t.scheduled_clock_seconds").alias(
            "scheduled_clock_seconds"
        ),

        F.col("t.scheduled_end_seconds").alias(
            "scheduled_end_seconds"
        ),

        F.col("t.scheduled_stop_count").alias(
            "scheduled_stop_count"
        ),

        F.col("t.timetable_operator_key").alias(
            "matched_operator_key"
        ),

        F.col("t.timetable_direction_key").alias(
            "matched_direction_key"
        )
    )
)

print(
    "candidate match rows:",
    f"{candidate_matches_df.count():,}"
)
# Out:
# candidate match rows: 9,546

# %%
# calculate whether operator values match
candidate_matches_df = (
    candidate_matches_df

    .withColumn(
        "operator_key_match",
        F.when(
            F.col("vehicle_operator_key")
            == F.col("matched_operator_key"),
            1
        ).otherwise(0)
    )

    .withColumn(
        "direction_key_match",
        F.when(
            F.col("vehicle_direction_key")
            == F.col("matched_direction_key"),
            1
        ).otherwise(0)
    )
)


# calculate the direct clock time difference
candidate_matches_df = (
    candidate_matches_df

    .withColumn(
        "raw_time_difference_seconds",
        F.abs(
            F.col("scheduled_clock_seconds")
            - F.col("aimed_start_seconds")
        )
    )

    .withColumn(
        "schedule_time_difference_seconds",
        F.when(
            F.col(
                "raw_time_difference_seconds"
            ).isNotNull(),

            F.least(
                F.col(
                    "raw_time_difference_seconds"
                ),

                F.lit(86400)
                - F.col(
                    "raw_time_difference_seconds"
                )
            )
        )
    )
)

print("candidate match quality values created")
# Out:
# candidate match quality values created

# %%
# define how timetable candidates should be ranked
best_match_window = (
    Window
    .partitionBy("observation_id")
    .orderBy(
        F.col(
            "operator_key_match"
        ).desc(),

        F.col(
            "direction_key_match"
        ).desc(),

        F.col(
            "schedule_time_difference_seconds"
        ).asc_nulls_last(),

        F.col(
            "matched_trip_id"
        ).asc_nulls_last()
    )
)


# rank the candidates and keep one match per observation
joined_df = (
    candidate_matches_df

    .withColumn(
        "match_rank",
        F.row_number().over(
            best_match_window
        )
    )

    .filter(
        F.col("match_rank") == 1
    )

    .drop(
        "match_rank",
        "raw_time_difference_seconds"
    )
)

print(
    "joined observation rows:",
    f"{joined_df.count():,}"
)
# Out:
# [Stage 133:>                                                        (0 + 4) / 4]
# joined observation rows: 9,546

# %%
# create match status and confidence columns
joined_df = (
    joined_df

    .withColumn(
        "is_timetable_matched",
        F.when(
            F.col(
                "matched_trip_id"
            ).isNotNull(),
            1
        ).otherwise(0)
    )

    .withColumn(
        "match_quality",
        F.when(
            F.col(
                "matched_trip_id"
            ).isNull(),
            "unmatched"
        )

        .when(
            (
                F.col(
                    "schedule_time_difference_seconds"
                ) <= 900
            )
            & (
                F.col(
                    "operator_key_match"
                ) == 1
            ),
            "high"
        )

        .when(
            F.col(
                "schedule_time_difference_seconds"
            ) <= 1800,
            "medium"
        )

        .when(
            F.col(
                "schedule_time_difference_seconds"
            ).isNull(),
            "journey and line only"
        )

        .otherwise(
            "low"
        )
    )

    .withColumn(
        "selected_line_method",
        F.lit(
            selected_line_method
        )
    )

    .withColumn(
        "selected_journey_method",
        F.lit(
            selected_journey_method
        )
    )
)

print("match status columns created")
# Out:
# match status columns created

# %%
# count original vehicle observations
original_vehicle_count = (
    vehicle_prepared_df.count()
)

# count final joined observations
final_joined_count = (
    joined_df.count()
)

print(
    "original vehicle observations:",
    f"{original_vehicle_count:,}"
)

print(
    "final joined observations:",
    f"{final_joined_count:,}"
)

# stop when joining creates or removes observation rows
if final_joined_count != original_vehicle_count:
    raise ValueError(
        "final joined rows do not match vehicle observations"
    )

print("one final row exists for every vehicle observation")
# Out:
# original vehicle observations: 9,546
# final joined observations: 9,546
# one final row exists for every vehicle observation

# %%
# count successfully matched observations
matched_vehicle_observations = (
    joined_df
    .filter(
        F.col(
            "is_timetable_matched"
        ) == 1
    )
    .count()
)

# calculate unmatched observations
unmatched_vehicle_observations = (
    final_joined_count
    - matched_vehicle_observations
)

# calculate the match percentage
match_rate = (
    matched_vehicle_observations
    / final_joined_count
    * 100
    if final_joined_count > 0
    else 0
)

print(
    "total vehicle observations:",
    f"{final_joined_count:,}"
)

print(
    "matched observations:",
    f"{matched_vehicle_observations:,}"
)

print(
    "unmatched observations:",
    f"{unmatched_vehicle_observations:,}"
)

print(
    "join match rate:",
    f"{match_rate:.2f}%"
)
# Out:
# total vehicle observations: 9,546
# matched observations: 17
# unmatched observations: 9,529
# join match rate: 0.18%

# %%
# count observations in every match quality category
match_quality_summary = (
    joined_df
    .groupBy(
        "match_quality"
    )
    .agg(
        F.count("*").alias(
            "observation_count"
        )
    )
    .orderBy(
        F.desc(
            "observation_count"
        )
    )
)

match_quality_summary.show(
    truncate=False
)
# Out:
# +-------------+-----------------+
# |match_quality|observation_count|
# +-------------+-----------------+
# |unmatched    |9529             |
# |low          |17               |
# +-------------+-----------------+

# %%
# display sample successfully matched observations
joined_df.filter(
    F.col(
        "is_timetable_matched"
    ) == 1
).select(
    "vehicle_ref",
    "operator_ref",
    "line_ref",
    "dated_vehicle_journey_ref",
    "recorded_at_time",
    "origin_aimed_departure_time",
    "matched_trip_id",
    "matched_route_short_name",
    "matched_vehicle_journey_code",
    "scheduled_start_seconds",
    "schedule_time_difference_seconds",
    "operator_key_match",
    "direction_key_match",
    "match_quality"
).show(
    20,
    truncate=False
)
# Out:
# [Stage 177:>                                                        (0 + 4) / 4]
# +-----------+------------+--------+-------------------------+-------------------+---------------------------+------------------------------------------+------------------------+----------------------------+-----------------------+--------------------------------+------------------+-------------------+-------------+
# |vehicle_ref|operator_ref|line_ref|dated_vehicle_journey_ref|recorded_at_time   |origin_aimed_departure_time|matched_trip_id                           |matched_route_short_name|matched_vehicle_journey_code|scheduled_start_seconds|schedule_time_difference_seconds|operator_key_match|direction_key_match|match_quality|
# +-----------+------------+--------+-------------------------+-------------------+---------------------------+------------------------------------------+------------------------+----------------------------+-----------------------+--------------------------------+------------------+-------------------+-------------+
# |2130       |TNXB        |29      |1                        |2026-07-14 05:34:50|2026-07-14 05:30:00        |VJ682dcc5faee2da22206667cb5abc13ff96116996|29                      |1                           |27360                  |7560                            |0                 |0                  |low          |
# |2129       |TNXB        |31      |6                        |2026-07-14 05:34:50|2026-07-14 05:30:00        |VJ8c5b9ba8b4d4ba7f7738c8a95ce221abfe51b57a|31                      |6                           |62100                  |42300                           |0                 |0                  |low          |
# |7516       |TNXB        |4       |3                        |2026-07-14 05:34:44|2026-07-14 05:00:00        |VJbf2bb6294567af5ea7e447053d2b1ce9c97a357e|4                       |3                           |40500                  |22500                           |0                 |0                  |low          |
# |2113       |TNXB        |71      |1                        |2026-07-14 05:34:50|2026-07-14 05:32:00        |VJ0462bd5c00970b6fbf2e807a5748a582e9f4ef42|71                      |1                           |30000                  |10080                           |0                 |0                  |low          |
# |2001       |TNXB        |69      |22                       |2026-07-13 11:39:27|2026-07-13 11:00:00        |VJ50049cc2e7f584291bd42acf4e297b2c36099aa4|69                      |22                          |44700                  |5100                            |0                 |0                  |low          |
# |2083       |TNXB        |71      |20                       |2026-07-13 09:44:51|2026-07-13 08:42:00        |VJce0d54c48cbc60b05ce2e809481d82cc84353d53|71                      |20                          |62400                  |31080                           |0                 |0                  |low          |
# |1788       |TNXB        |71      |23                       |2026-07-13 11:39:31|2026-07-13 10:46:00        |VJ43f9ed6f2276e88a6e0bca40e65544754510144f|71                      |23                          |76200                  |37440                           |0                 |0                  |low          |
# |2079       |TNXB        |71      |2                        |2026-07-14 05:34:48|2026-07-14 05:18:00        |VJb6ef184a45e421bc99fabbbfed7328071d4af5af|71                      |2                           |33600                  |14520                           |0                 |0                  |low          |
# |2072       |TNXB        |71      |20                       |2026-07-14 09:45:13|2026-07-14 08:42:00        |VJce0d54c48cbc60b05ce2e809481d82cc84353d53|71                      |20                          |62400                  |31080                           |0                 |0                  |low          |
# |2072       |TNXB        |71      |20                       |2026-07-14 09:45:13|2026-07-14 08:42:00        |VJce0d54c48cbc60b05ce2e809481d82cc84353d53|71                      |20                          |62400                  |31080                           |0                 |0                  |low          |
# |6702       |TNXB        |4       |5                        |2026-07-14 05:34:50|2026-07-14 05:30:00        |VJfb440819a3b9742468d5cb2a130b80a45c37f12e|4                       |5                           |47700                  |27900                           |0                 |0                  |low          |
# |2067       |TNXB        |69      |24                       |2026-07-13 11:39:32|2026-07-13 11:30:00        |VJe412b0dcac3da8afe2e67f34e3fd926b370f7902|69                      |24                          |52980                  |11580                           |0                 |0                  |low          |
# |2012       |TNXB        |69      |23                       |2026-07-13 11:39:28|2026-07-13 11:30:00        |VJc0c30681a13536a65337c644ebb67e20606ed4c4|69                      |23                          |44700                  |3300                            |0                 |0                  |low          |
# |1812       |TNXB        |71      |15                       |2026-07-13 09:54:40|2026-07-13 08:46:00        |VJ0b1414c8e997711805799398e0c07907b5a7e1c2|71                      |15                          |40800                  |9240                            |0                 |0                  |low          |
# |2072       |TNXB        |71      |20                       |2026-07-14 09:45:13|2026-07-14 08:42:00        |VJce0d54c48cbc60b05ce2e809481d82cc84353d53|71                      |20                          |62400                  |31080                           |0                 |0                  |low          |
# |Z4009      |TCVW        |11      |14                       |2026-07-13 08:26:47|2026-07-13 07:16:00        |VJ35453f90c759743d534e608de465dd10c07fb088|11                      |14                          |35040                  |8880                            |0                 |0                  |low          |
# |2002       |TNXB        |69      |21                       |2026-07-13 11:39:32|2026-07-13 11:00:00        |VJd5d07f57c5330e2f44a6407a18b226c32c45225d|69                      |21                          |44700                  |5100                            |0                 |0                  |low          |
# +-----------+------------+--------+-------------------------+-------------------+---------------------------+------------------------------------------+------------------------+----------------------------+-----------------------+--------------------------------+------------------+-------------------+-------------+

# %%
# display sample unmatched observations
joined_df.filter(
    F.col(
        "is_timetable_matched"
    ) == 0
).select(
    "source_file",
    "vehicle_ref",
    "operator_ref",
    "line_ref",
    "published_line_name",
    "dated_vehicle_journey_ref",
    "direction_ref",
    "recorded_at_time"
).show(
    20,
    truncate=False
)
# Out:
# +-------------------------------------+-----------+------------+--------+-------------------+-------------------------+-------------+-------------------+
# |source_file                          |vehicle_ref|operator_ref|line_ref|published_line_name|dated_vehicle_journey_ref|direction_ref|recorded_at_time   |
# +-------------------------------------+-----------+------------+--------+-------------------+-------------------------+-------------+-------------------+
# |nx_west_midlands_20260711T174953Z.xml|E063       |TCVW        |X1      |X1                 |139                      |outbound     |2026-07-11 03:16:23|
# |nx_west_midlands_20260714T163040Z.xml|E240       |TNXB        |2       |2                  |33                       |outbound     |2026-07-14 09:37:06|
# |nx_west_midlands_20260713T103956Z.xml|E1213      |TNXB        |16      |16                 |130                      |inbound      |2026-07-13 11:39:28|
# |nx_west_midlands_20260711T174953Z.xml|E232       |TNXB        |50      |50                 |234                      |inbound      |2026-07-11 18:48:40|
# |nx_west_midlands_20260714T163040Z.xml|5509       |TNXB        |24      |24                 |256                      |inbound      |2026-07-14 17:25:32|
# |nx_west_midlands_20260711T174953Z.xml|E1172      |TNXB        |59      |59                 |177                      |outbound     |2026-07-11 18:48:37|
# |nx_west_midlands_20260714T153030Z.xml|6930       |TNXB        |9       |9                  |134                      |inbound      |2026-07-14 16:30:07|
# |nx_west_midlands_20260713T172521Z.xml|2158       |TCVW        |17A     |17A                |97                       |outbound     |2026-07-13 18:24:57|
# |nx_west_midlands_20260714T153030Z.xml|6723       |TNXB        |936     |936                |87                       |outbound     |2026-07-14 16:29:59|
# |nx_west_midlands_20260712T041703Z.xml|E040       |TCVW        |3       |3                  |908                      |inbound      |2026-07-11 23:57:01|
# |nx_west_midlands_20260714T163044Z.xml|6828       |TNXB        |45      |45                 |51                       |outbound     |2026-07-14 09:35:54|
# |nx_west_midlands_20260714T043513Z.xml|6130       |TNXB        |72      |72                 |151                      |outbound     |2026-07-13 20:53:56|
# |nx_west_midlands_20260714T163040Z.xml|5425       |TNXB        |33      |33                 |629                      |outbound     |2026-07-14 16:52:52|
# |nx_west_midlands_20260714T043513Z.xml|2016       |TNXB        |4       |4                  |835                      |outbound     |2026-07-13 18:56:41|
# |nx_west_midlands_20260712T041703Z.xml|2144       |TNXB        |29      |29                 |164                      |inbound      |2026-07-11 17:18:43|
# |nx_west_midlands_20260714T153030Z.xml|821        |TNXB        |2       |2                  |842                      |inbound      |2026-07-14 16:30:07|
# |nx_west_midlands_20260714T153030Z.xml|E205       |TNXB        |16      |16                 |231                      |outbound     |2026-07-14 16:29:58|
# |nx_west_midlands_20260714T163044Z.xml|6866       |TNXB        |X12     |X12                |107                      |outbound     |2026-07-14 17:26:00|
# |nx_west_midlands_20260711T174953Z.xml|E074       |TCVW        |6       |6                  |120                      |inbound      |2026-07-11 17:24:43|
# |nx_west_midlands_20260712T041703Z.xml|2135       |TNXB        |70      |70                 |49                       |outbound     |2026-07-11 19:20:29|
# +-------------------------------------+-----------+------------+--------+-------------------+-------------------------+-------------+-------------------+
# only showing top 20 rows

# %%
# distribute the joined dataset across four route based partitions
joined_df = joined_df.repartition(
    4,
    "line_ref"
)

# cache the dataset for later analysis
joined_df.cache()

# trigger spark processing
joined_count = joined_df.count()

print(
    "final joined rows:",
    f"{joined_count:,}"
)

print(
    "joined partitions:",
    joined_df.rdd.getNumPartitions()
)
# Out:
# final joined rows: 9,546
# joined partitions: 4

# %%
# register the joined dataframe as a temporary sql table
joined_df.createOrReplaceTempView(
    "joined_transport_data"
)

print("temporary sql view created")
print("view name: joined_transport_data")
# Out:
# temporary sql view created
# view name: joined_transport_data

# %%
# calculate match rates for each bus line
join_line_summary = spark.sql("""
    SELECT
        line_ref,
        published_line_name,
        COUNT(*) AS total_observations,
        SUM(is_timetable_matched) AS matched_observations,
        ROUND(
            SUM(is_timetable_matched) * 100.0
            / COUNT(*),
            2
        ) AS match_rate_percent
    FROM joined_transport_data
    GROUP BY
        line_ref,
        published_line_name
    ORDER BY
        total_observations DESC
    LIMIT 20
""")

join_line_summary.show(
    truncate=False
)
# Out:
# +--------+-------------------+------------------+--------------------+------------------+
# |line_ref|published_line_name|total_observations|matched_observations|match_rate_percent|
# +--------+-------------------+------------------+--------------------+------------------+
# |6       |6                  |333               |0                   |0.00              |
# |11A     |11A                |250               |0                   |0.00              |
# |9       |9                  |243               |0                   |0.00              |
# |4       |4                  |235               |2                   |0.85              |
# |74      |74                 |234               |0                   |0.00              |
# |16      |16                 |214               |0                   |0.00              |
# |7       |7                  |207               |0                   |0.00              |
# |11C     |11C                |203               |0                   |0.00              |
# |3       |3                  |198               |0                   |0.00              |
# |14      |14                 |175               |0                   |0.00              |
# |8       |8                  |173               |0                   |0.00              |
# |2       |2                  |172               |0                   |0.00              |
# |1       |1                  |171               |0                   |0.00              |
# |50      |50                 |167               |0                   |0.00              |
# |11      |11                 |160               |1                   |0.63              |
# |X1      |X1                 |151               |0                   |0.00              |
# |5       |5                  |148               |0                   |0.00              |
# |18      |18                 |135               |0                   |0.00              |
# |87      |87                 |125               |0                   |0.00              |
# |49      |49                 |123               |0                   |0.00              |
# +--------+-------------------+------------------+--------------------+------------------+

# %%
# display how spark plans the joining operations
joined_df.explain(
    mode="formatted"
)
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (38)
# +- == Final Plan ==
#    TableCacheQueryStage (37), Statistics(sizeInBytes=4.3 MiB, rowCount=9.55E+3)
#    +- InMemoryTableScan (1)
#          +- InMemoryRelation (2)
#                +- AdaptiveSparkPlan (36)
#                   +- Exchange (35)
#                      +- Project (34)
#                         +- Filter (33)
#                            +- Window (32)
#                               +- WindowGroupLimit (31)
#                                  +- Sort (30)
#                                     +- Exchange (29)
#                                        +- WindowGroupLimit (28)
#                                           +- Sort (27)
#                                              +- Project (26)
#                                                 +- Project (25)
#                                                    +- SortMergeJoin LeftOuter (24)
#                                                       :- Sort (9)
#                                                       :  +- Exchange (8)
#                                                       :     +- InMemoryTableScan (3)
#                                                       :           +- InMemoryRelation (4)
#                                                       :                 +- * Project (7)
#                                                       :                    +- * ColumnarToRow (6)
#                                                       :                       +- Scan parquet  (5)
#                                                       +- Sort (23)
#                                                          +- Exchange (22)
#                                                             +- Filter (21)
#                                                                +- InMemoryTableScan (10)
#                                                                      +- InMemoryRelation (11)
#                                                                            +- AdaptiveSparkPlan (20)
#                                                                               +- Project (19)
#                                                                                  +- HashAggregate (18)
#                                                                                     +- Exchange (17)
#                                                                                        +- HashAggregate (16)
#                                                                                           +- HashAggregate (15)
#                                                                                              +- Exchange (14)
#                                                                                                 +- HashAggregate (13)
#                                                                                                    +- Scan parquet  (12)
# +- == Initial Plan ==
#    InMemoryTableScan (1)
#       +- InMemoryRelation (2)
#             +- AdaptiveSparkPlan (36)
#                +- Exchange (35)
#                   +- Project (34)
#                      +- Filter (33)
#                         +- Window (32)
#                            +- WindowGroupLimit (31)
#                               +- Sort (30)
#                                  +- Exchange (29)
#                                     +- WindowGroupLimit (28)
#                                        +- Sort (27)
#                                           +- Project (26)
#                                              +- Project (25)
#                                                 +- SortMergeJoin LeftOuter (24)
#                                                    :- Sort (9)
#                                                    :  +- Exchange (8)
#                                                    :     +- InMemoryTableScan (3)
#                                                    :           +- InMemoryRelation (4)
#                                                    :                 +- * Project (7)
#                                                    :                    +- * ColumnarToRow (6)
#                                                    :                       +- Scan parquet  (5)
#                                                    +- Sort (23)
#                                                       +- Exchange (22)
#                                                          +- Filter (21)
#                                                             +- InMemoryTableScan (10)
#                                                                   +- InMemoryRelation (11)
#                                                                         +- AdaptiveSparkPlan (20)
#                                                                            +- Project (19)
#                                                                               +- HashAggregate (18)
#                                                                                  +- Exchange (17)
#                                                                                     +- HashAggregate (16)
#                                                                                        +- HashAggregate (15)
#                                                                                           +- Exchange (14)
#                                                                                              +- HashAggregate (13)
#                                                                                                 +- Scan parquet  (12)
#
#
# (1) InMemoryTableScan
# Output [51]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268, matched_trip_id#10003, matched_service_id#10004, matched_route_id#10005, matched_route_short_name#10006, matched_vehicle_journey_code#10007, matched_direction_id#10008, matched_trip_headsign#10009, scheduled_start_seconds#10010, scheduled_clock_seconds#10011, scheduled_end_seconds#10012, scheduled_stop_count#10013L, matched_operator_key#10014, matched_direction_key#10015, operator_key_match#11359, direction_key_match#11405, schedule_time_difference_seconds#11500, is_timetable_matched#12949, match_quality#12998, selected_line_method#13048, selected_journey_method#13099]
# Arguments: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 27 more fields]
#
# (2) InMemoryRelation
# Arguments: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 27 more fields], CachedRDDBuilder(org.apache.spark.sql.execution.columnar.DefaultCachedBatchSerializer@43d6ce68,StorageLevel(disk, memory, deserialized, 1 replicas),AdaptiveSparkPlan isFinalPlan=true
# +- == Final Plan ==
#    ShuffleQueryStage 5
#    +- Exchange hashpartitioning(line_ref#49, 4), REPARTITION_BY_NUM, [plan_id=5864]
#       +- *(6) Project [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 27 more fields]
#          +- *(6) Filter (match_rank#11550 = 1)
#             +- Window [row_number() windowspecdefinition(observation_id#1268, operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS match_rank#11550], [observation_id#1268], [operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST]
#                +- WindowGroupLimit [observation_id#1268], [operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST], row_number(), 1, Final
#                   +- *(5) Sort [observation_id#1268 ASC NULLS FIRST, operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST], false, 0
#                      +- AQEShuffleRead coalesced
#                         +- ShuffleQueryStage 4
#                            +- Exchange hashpartitioning(observation_id#1268, 4), ENSURE_REQUIREMENTS, [plan_id=5792]
#                               +- WindowGroupLimit [observation_id#1268], [operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST], row_number(), 1, Partial
#                                  +- *(4) Sort [observation_id#1268 ASC NULLS FIRST, operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST], false, 0
#                                     +- *(4) Project [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 23 more fields]
#                                        +- *(4) Project [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 23 more fields]
#                                           +- *(4) SortMergeJoin [vehicle_journey_full_key#1150, vehicle_line_ref_key#1097], [timetable_journey_full_key#375, timetable_line_key#359], LeftOuter, (isnotnull(vehicle_journey_full_key#1150) AND NOT (vehicle_journey_full_key#1150 = ))
#                                              :- *(2) Sort [vehicle_journey_full_key#1150 ASC NULLS FIRST, vehicle_line_ref_key#1097 ASC NULLS FIRST], false, 0
#                                              :  +- ShuffleQueryStage 2
#                                              :     +- Exchange hashpartitioning(vehicle_journey_full_key#1150, vehicle_line_ref_key#1097, 4), ENSURE_REQUIREMENTS, [plan_id=5533]
#                                              :        +- TableCacheQueryStage 0
#                                              :           +- InMemoryTableScan [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 7 more fields]
#                                              :                 +- InMemoryRelation [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 7 more fields], StorageLevel(disk, memory, deserialized, 1 replicas)
#                                              :                       +- *(1) Project [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, upper(regexp_replace(trim(operator_ref#48, None), [^A-Za-z0-9], , 1)) AS vehicle_operator_key#1072, ... 7 more fields]
#                                              :                          +- *(1) ColumnarToRow
#                                              :                             +- FileScan parquet [source_file#44,snapshot_time#45,recorded_at_time#46,valid_until_time#47,operator_ref#48,line_ref#49,published_line_name#50,direction_ref#51,dated_vehicle_journey_ref#52,journey_pattern_ref#53,vehicle_ref#54,block_ref#55,origin_ref#56,destination_ref#57,destination_name#58,origin_aimed_departure_time#59,longitude#60,latitude#61,bearing#62,observation_date#63,observation_hour#64,observation_day_of_week#65,observation_age_seconds#66L] Batched: true, DataFilters: [], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/Users/babitaadhikari/Desktop/bus-disruption-platform/data/proces..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<source_file:string,snapshot_time:timestamp,recorded_at_time:timestamp,valid_until_time:tim...
#                                              +- *(3) Sort [timetable_journey_full_key#375 ASC NULLS FIRST, timetable_line_key#359 ASC NULLS FIRST], false, 0
#                                                 +- ShuffleQueryStage 3
#                                                    +- Exchange hashpartitioning(timetable_journey_full_key#375, timetable_line_key#359, 4), ENSURE_REQUIREMENTS, [plan_id=5638]
#                                                       +- *(1) Filter ((isnotnull(timetable_journey_full_key#375) AND NOT (timetable_journey_full_key#375 = )) AND isnotnull(timetable_line_key#359))
#                                                          +- TableCacheQueryStage 1
#                                                             +- InMemoryTableScan [route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, scheduled_start_seconds#212, scheduled_end_seconds#214, scheduled_stop_count#219L, timetable_operator_key#344, timetable_line_key#359, timetable_journey_full_key#375, timetable_direction_key#410, scheduled_clock_seconds#429], [isnotnull(timetable_journey_full_key#375), NOT (timetable_journey_full_key#375 = ), isnotnull(timetable_line_key#359)]
#                                                                   +- InMemoryRelation [agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, scheduled_start_seconds#212, scheduled_end_seconds#214, first_stop_sequence#216, last_stop_sequence#218, scheduled_stop_count#219L, timetable_operator_key#344, timetable_line_key#359, timetable_journey_full_key#375, timetable_journey_tail_key#392, timetable_direction_key#410, scheduled_clock_seconds#429], StorageLevel(disk, memory, deserialized, 1 replicas)
#                                                                         +- AdaptiveSparkPlan isFinalPlan=false
#                                                                            +- Project [agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, scheduled_start_seconds#212, scheduled_end_seconds#214, first_stop_sequence#216, last_stop_sequence#218, scheduled_stop_count#219L, timetable_operator_key#344, timetable_line_key#359, timetable_journey_full_key#375, timetable_journey_tail_key#392, timetable_direction_key#410, pmod(scheduled_start_seconds#212, 86400) AS scheduled_clock_seconds#429]
#                                                                               +- HashAggregate(keys=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10], functions=[min(departure_seconds#18), max(arrival_seconds#17), min(stop_sequence#14), max(stop_sequence#14), count(distinct stop_id#11)], output=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, scheduled_start_seconds#212, scheduled_end_seconds#214, first_stop_sequence#216, last_stop_sequence#218, scheduled_stop_count#219L, timetable_operator_key#344, timetable_line_key#359, timetable_journey_full_key#375, timetable_journey_tail_key#392, timetable_direction_key#410])
#                                                                                  +- Exchange hashpartitioning(agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, 4), ENSURE_REQUIREMENTS, [plan_id=5452]
#                                                                                     +- HashAggregate(keys=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10], functions=[merge_min(departure_seconds#18), merge_max(arrival_seconds#17), merge_min(stop_sequence#14), merge_max(stop_sequence#14), partial_count(distinct stop_id#11)], output=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, min#292, max#294, min#296, max#298, count#301L])
#                                                                                        +- HashAggregate(keys=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11], functions=[merge_min(departure_seconds#18), merge_max(arrival_seconds#17), merge_min(stop_sequence#14), merge_max(stop_sequence#14)], output=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11, min#292, max#294, min#296, max#298])
#                                                                                           +- Exchange hashpartitioning(agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11, 4), ENSURE_REQUIREMENTS, [plan_id=5448]
#                                                                                              +- HashAggregate(keys=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11], functions=[partial_min(departure_seconds#18), partial_max(arrival_seconds#17), partial_min(stop_sequence#14), partial_max(stop_sequence#14)], output=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11, min#292, max#294, min#296, max#298])
#                                                                                                 +- FileScan parquet [agency_noc#2,route_id#3,route_short_name#4,service_id#6,trip_id#7,vehicle_journey_code#8,trip_headsign#9,direction_id#10,stop_id#11,stop_sequence#14,arrival_seconds#17,departure_seconds#18] Batched: true, DataFilters: [], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/Users/babitaadhikari/Desktop/bus-disruption-platform/data/proces..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<agency_noc:string,route_id:string,route_short_name:string,service_id:string,trip_id:string...
# +- == Initial Plan ==
#    Exchange hashpartitioning(line_ref#49, 4), REPARTITION_BY_NUM, [plan_id=5441]
#    +- Project [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 27 more fields]
#       +- Filter (match_rank#11550 = 1)
#          +- Window [row_number() windowspecdefinition(observation_id#1268, operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS match_rank#11550], [observation_id#1268], [operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST]
#             +- WindowGroupLimit [observation_id#1268], [operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST], row_number(), 1, Final
#                +- Sort [observation_id#1268 ASC NULLS FIRST, operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST], false, 0
#                   +- Exchange hashpartitioning(observation_id#1268, 4), ENSURE_REQUIREMENTS, [plan_id=5435]
#                      +- WindowGroupLimit [observation_id#1268], [operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST], row_number(), 1, Partial
#                         +- Sort [observation_id#1268 ASC NULLS FIRST, operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST], false, 0
#                            +- Project [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 23 more fields]
#                               +- Project [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 23 more fields]
#                                  +- SortMergeJoin [vehicle_journey_full_key#1150, vehicle_line_ref_key#1097], [timetable_journey_full_key#375, timetable_line_key#359], LeftOuter, (isnotnull(vehicle_journey_full_key#1150) AND NOT (vehicle_journey_full_key#1150 = ))
#                                     :- Sort [vehicle_journey_full_key#1150 ASC NULLS FIRST, vehicle_line_ref_key#1097 ASC NULLS FIRST], false, 0
#                                     :  +- Exchange hashpartitioning(vehicle_journey_full_key#1150, vehicle_line_ref_key#1097, 4), ENSURE_REQUIREMENTS, [plan_id=5424]
#                                     :     +- InMemoryTableScan [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 7 more fields]
#                                     :           +- InMemoryRelation [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 7 more fields], StorageLevel(disk, memory, deserialized, 1 replicas)
#                                     :                 +- *(1) Project [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, upper(regexp_replace(trim(operator_ref#48, None), [^A-Za-z0-9], , 1)) AS vehicle_operator_key#1072, ... 7 more fields]
#                                     :                    +- *(1) ColumnarToRow
#                                     :                       +- FileScan parquet [source_file#44,snapshot_time#45,recorded_at_time#46,valid_until_time#47,operator_ref#48,line_ref#49,published_line_name#50,direction_ref#51,dated_vehicle_journey_ref#52,journey_pattern_ref#53,vehicle_ref#54,block_ref#55,origin_ref#56,destination_ref#57,destination_name#58,origin_aimed_departure_time#59,longitude#60,latitude#61,bearing#62,observation_date#63,observation_hour#64,observation_day_of_week#65,observation_age_seconds#66L] Batched: true, DataFilters: [], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/Users/babitaadhikari/Desktop/bus-disruption-platform/data/proces..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<source_file:string,snapshot_time:timestamp,recorded_at_time:timestamp,valid_until_time:tim...
#                                     +- Sort [timetable_journey_full_key#375 ASC NULLS FIRST, timetable_line_key#359 ASC NULLS FIRST], false, 0
#                                        +- Exchange hashpartitioning(timetable_journey_full_key#375, timetable_line_key#359, 4), ENSURE_REQUIREMENTS, [plan_id=5425]
#                                           +- Filter ((isnotnull(timetable_journey_full_key#375) AND NOT (timetable_journey_full_key#375 = )) AND isnotnull(timetable_line_key#359))
#                                              +- InMemoryTableScan [route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, scheduled_start_seconds#212, scheduled_end_seconds#214, scheduled_stop_count#219L, timetable_operator_key#344, timetable_line_key#359, timetable_journey_full_key#375, timetable_direction_key#410, scheduled_clock_seconds#429], [isnotnull(timetable_journey_full_key#375), NOT (timetable_journey_full_key#375 = ), isnotnull(timetable_line_key#359)]
#                                                    +- InMemoryRelation [agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, scheduled_start_seconds#212, scheduled_end_seconds#214, first_stop_sequence#216, last_stop_sequence#218, scheduled_stop_count#219L, timetable_operator_key#344, timetable_line_key#359, timetable_journey_full_key#375, timetable_journey_tail_key#392, timetable_direction_key#410, scheduled_clock_seconds#429], StorageLevel(disk, memory, deserialized, 1 replicas)
#                                                          +- AdaptiveSparkPlan isFinalPlan=false
#                                                             +- Project [agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, scheduled_start_seconds#212, scheduled_end_seconds#214, first_stop_sequence#216, last_stop_sequence#218, scheduled_stop_count#219L, timetable_operator_key#344, timetable_line_key#359, timetable_journey_full_key#375, timetable_journey_tail_key#392, timetable_direction_key#410, pmod(scheduled_start_seconds#212, 86400) AS scheduled_clock_seconds#429]
#                                                                +- HashAggregate(keys=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10], functions=[min(departure_seconds#18), max(arrival_seconds#17), min(stop_sequence#14), max(stop_sequence#14), count(distinct stop_id#11)], output=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, scheduled_start_seconds#212, scheduled_end_seconds#214, first_stop_sequence#216, last_stop_sequence#218, scheduled_stop_count#219L, timetable_operator_key#344, timetable_line_key#359, timetable_journey_full_key#375, timetable_journey_tail_key#392, timetable_direction_key#410])
#                                                                   +- Exchange hashpartitioning(agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, 4), ENSURE_REQUIREMENTS, [plan_id=5452]
#                                                                      +- HashAggregate(keys=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10], functions=[merge_min(departure_seconds#18), merge_max(arrival_seconds#17), merge_min(stop_sequence#14), merge_max(stop_sequence#14), partial_count(distinct stop_id#11)], output=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, min#292, max#294, min#296, max#298, count#301L])
#                                                                         +- HashAggregate(keys=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11], functions=[merge_min(departure_seconds#18), merge_max(arrival_seconds#17), merge_min(stop_sequence#14), merge_max(stop_sequence#14)], output=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11, min#292, max#294, min#296, max#298])
#                                                                            +- Exchange hashpartitioning(agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11, 4), ENSURE_REQUIREMENTS, [plan_id=5448]
#                                                                               +- HashAggregate(keys=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11], functions=[partial_min(departure_seconds#18), partial_max(arrival_seconds#17), partial_min(stop_sequence#14), partial_max(stop_sequence#14)], output=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11, min#292, max#294, min#296, max#298])
#                                                                                  +- FileScan parquet [agency_noc#2,route_id#3,route_short_name#4,service_id#6,trip_id#7,vehicle_journey_code#8,trip_headsign#9,direction_id#10,stop_id#11,stop_sequence#14,arrival_seconds#17,departure_seconds#18] Batched: true, DataFilters: [], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/Users/babitaadhikari/Desktop/bus-disruption-platform/data/proces..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<agency_noc:string,route_id:string,route_short_name:string,service_id:string,trip_id:string...
# ,None)
#
# (3) InMemoryTableScan
# Output [31]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268]
# Arguments: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 7 more fields]
#
# (4) InMemoryRelation
# Arguments: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, ... 7 more fields], CachedRDDBuilder(org.apache.spark.sql.execution.columnar.DefaultCachedBatchSerializer@43d6ce68,StorageLevel(disk, memory, deserialized, 1 replicas),*(1) Project [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, upper(regexp_replace(trim(operator_ref#48, None), [^A-Za-z0-9], , 1)) AS vehicle_operator_key#1072, ... 7 more fields]
# +- *(1) ColumnarToRow
#    +- FileScan parquet [source_file#44,snapshot_time#45,recorded_at_time#46,valid_until_time#47,operator_ref#48,line_ref#49,published_line_name#50,direction_ref#51,dated_vehicle_journey_ref#52,journey_pattern_ref#53,vehicle_ref#54,block_ref#55,origin_ref#56,destination_ref#57,destination_name#58,origin_aimed_departure_time#59,longitude#60,latitude#61,bearing#62,observation_date#63,observation_hour#64,observation_day_of_week#65,observation_age_seconds#66L] Batched: true, DataFilters: [], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/Users/babitaadhikari/Desktop/bus-disruption-platform/data/proces..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<source_file:string,snapshot_time:timestamp,recorded_at_time:timestamp,valid_until_time:tim...
# ,None)
#
# (5) Scan parquet
# Output [23]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/babitaadhikari/Desktop/bus-disruption-platform/data/processed/vehicle_locations]
# ReadSchema: struct<source_file:string,snapshot_time:timestamp,recorded_at_time:timestamp,valid_until_time:timestamp,operator_ref:string,line_ref:string,published_line_name:string,direction_ref:string,dated_vehicle_journey_ref:string,journey_pattern_ref:string,vehicle_ref:string,block_ref:string,origin_ref:string,destination_ref:string,destination_name:string,origin_aimed_departure_time:timestamp,longitude:double,latitude:double,bearing:double,observation_date:date,observation_hour:int,observation_day_of_week:int,observation_age_seconds:bigint>
#
# (6) ColumnarToRow [codegen id : 1]
# Input [23]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L]
#
# (7) Project [codegen id : 1]
# Output [31]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, upper(regexp_replace(trim(operator_ref#48, None), [^A-Za-z0-9], , 1)) AS vehicle_operator_key#1072, upper(regexp_replace(trim(line_ref#49, None), [^A-Za-z0-9], , 1)) AS vehicle_line_ref_key#1097, upper(regexp_replace(trim(published_line_name#50, None), [^A-Za-z0-9], , 1)) AS vehicle_published_line_key#1123, upper(regexp_replace(trim(dated_vehicle_journey_ref#52, None), [^A-Za-z0-9], , 1)) AS vehicle_journey_full_key#1150, regexp_replace(regexp_extract(upper(trim(dated_vehicle_journey_ref#52, None)), ([^:/|]+)$, 1), [^A-Z0-9], , 1) AS vehicle_journey_tail_key#1178, upper(regexp_replace(trim(direction_ref#51, None), [^A-Za-z0-9], , 1)) AS vehicle_direction_key#1207, (((hour(origin_aimed_departure_time#59, Some(Europe/London)) * 3600) + (minute(origin_aimed_departure_time#59, Some(Europe/London)) * 60)) + second(origin_aimed_departure_time#59, Some(Europe/London))) AS aimed_start_seconds#1237, sha2(cast(concat_ws(||, coalesce(source_file#44, ), coalesce(vehicle_ref#54, ), coalesce(cast(recorded_at_time#46 as string), ), coalesce(line_ref#49, )) as binary), 256) AS observation_id#1268]
# Input [23]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L]
#
# (8) Exchange
# Input [31]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268]
# Arguments: hashpartitioning(vehicle_journey_full_key#1150, vehicle_line_ref_key#1097, 4), ENSURE_REQUIREMENTS, [plan_id=5971]
#
# (9) Sort
# Input [31]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268]
# Arguments: [vehicle_journey_full_key#1150 ASC NULLS FIRST, vehicle_line_ref_key#1097 ASC NULLS FIRST], false, 0
#
# (10) InMemoryTableScan
# Output [15]: [route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, scheduled_start_seconds#212, scheduled_end_seconds#214, scheduled_stop_count#219L, timetable_operator_key#344, timetable_line_key#359, timetable_journey_full_key#375, timetable_direction_key#410, scheduled_clock_seconds#429]
# Arguments: [route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, scheduled_start_seconds#212, scheduled_end_seconds#214, scheduled_stop_count#219L, timetable_operator_key#344, timetable_line_key#359, timetable_journey_full_key#375, timetable_direction_key#410, scheduled_clock_seconds#429], [isnotnull(timetable_journey_full_key#375), NOT (timetable_journey_full_key#375 = ), isnotnull(timetable_line_key#359)]
#
# (11) InMemoryRelation
# Arguments: [agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, scheduled_start_seconds#212, scheduled_end_seconds#214, first_stop_sequence#216, last_stop_sequence#218, scheduled_stop_count#219L, timetable_operator_key#344, timetable_line_key#359, timetable_journey_full_key#375, timetable_journey_tail_key#392, timetable_direction_key#410, scheduled_clock_seconds#429], CachedRDDBuilder(org.apache.spark.sql.execution.columnar.DefaultCachedBatchSerializer@43d6ce68,StorageLevel(disk, memory, deserialized, 1 replicas),AdaptiveSparkPlan isFinalPlan=true
# +- == Final Plan ==
#    *(3) Project [agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, scheduled_start_seconds#212, scheduled_end_seconds#214, first_stop_sequence#216, last_stop_sequence#218, scheduled_stop_count#219L, timetable_operator_key#344, timetable_line_key#359, timetable_journey_full_key#375, timetable_journey_tail_key#392, timetable_direction_key#410, pmod(scheduled_start_seconds#212, 86400) AS scheduled_clock_seconds#429]
#    +- *(3) HashAggregate(keys=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10], functions=[min(departure_seconds#18), max(arrival_seconds#17), min(stop_sequence#14), max(stop_sequence#14), count(distinct stop_id#11)], output=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, scheduled_start_seconds#212, scheduled_end_seconds#214, first_stop_sequence#216, last_stop_sequence#218, scheduled_stop_count#219L, timetable_operator_key#344, timetable_line_key#359, timetable_journey_full_key#375, timetable_journey_tail_key#392, timetable_direction_key#410])
#       +- ShuffleQueryStage 1
#          +- Exchange hashpartitioning(agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, 4), ENSURE_REQUIREMENTS, [plan_id=489]
#             +- *(2) HashAggregate(keys=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10], functions=[merge_min(departure_seconds#18), merge_max(arrival_seconds#17), merge_min(stop_sequence#14), merge_max(stop_sequence#14), partial_count(distinct stop_id#11)], output=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, min#292, max#294, min#296, max#298, count#301L])
#                +- *(2) HashAggregate(keys=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11], functions=[merge_min(departure_seconds#18), merge_max(arrival_seconds#17), merge_min(stop_sequence#14), merge_max(stop_sequence#14)], output=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11, min#292, max#294, min#296, max#298])
#                   +- ShuffleQueryStage 0
#                      +- Exchange hashpartitioning(agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11, 4), ENSURE_REQUIREMENTS, [plan_id=461]
#                         +- *(1) HashAggregate(keys=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11], functions=[partial_min(departure_seconds#18), partial_max(arrival_seconds#17), partial_min(stop_sequence#14), partial_max(stop_sequence#14)], output=[agency_noc#2, route_id#3, route_short_name#4, service_id#6, trip_id#7, vehicle_journey_code#8, trip_headsign#9, direction_id#10, stop_id#11, min#292, max#294, min#296, max#298])
#                            +- *(1) ColumnarToRow
# ...
# Arguments: [observation_id#1268], [operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST], row_number(), 1, Partial
#
# (29) Exchange
# Input [47]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268, matched_trip_id#10003, matched_service_id#10004, matched_route_id#10005, matched_route_short_name#10006, matched_vehicle_journey_code#10007, matched_direction_id#10008, matched_trip_headsign#10009, scheduled_start_seconds#212, scheduled_clock_seconds#429, scheduled_end_seconds#214, scheduled_stop_count#219L, matched_operator_key#10014, matched_direction_key#10015, operator_key_match#11359, direction_key_match#11405, schedule_time_difference_seconds#11500]
# Arguments: hashpartitioning(observation_id#1268, 4), ENSURE_REQUIREMENTS, [plan_id=5982]
#
# (30) Sort
# Input [47]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268, matched_trip_id#10003, matched_service_id#10004, matched_route_id#10005, matched_route_short_name#10006, matched_vehicle_journey_code#10007, matched_direction_id#10008, matched_trip_headsign#10009, scheduled_start_seconds#212, scheduled_clock_seconds#429, scheduled_end_seconds#214, scheduled_stop_count#219L, matched_operator_key#10014, matched_direction_key#10015, operator_key_match#11359, direction_key_match#11405, schedule_time_difference_seconds#11500]
# Arguments: [observation_id#1268 ASC NULLS FIRST, operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST], false, 0
#
# (31) WindowGroupLimit
# Input [47]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268, matched_trip_id#10003, matched_service_id#10004, matched_route_id#10005, matched_route_short_name#10006, matched_vehicle_journey_code#10007, matched_direction_id#10008, matched_trip_headsign#10009, scheduled_start_seconds#212, scheduled_clock_seconds#429, scheduled_end_seconds#214, scheduled_stop_count#219L, matched_operator_key#10014, matched_direction_key#10015, operator_key_match#11359, direction_key_match#11405, schedule_time_difference_seconds#11500]
# Arguments: [observation_id#1268], [operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST], row_number(), 1, Final
#
# (32) Window
# Input [47]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268, matched_trip_id#10003, matched_service_id#10004, matched_route_id#10005, matched_route_short_name#10006, matched_vehicle_journey_code#10007, matched_direction_id#10008, matched_trip_headsign#10009, scheduled_start_seconds#212, scheduled_clock_seconds#429, scheduled_end_seconds#214, scheduled_stop_count#219L, matched_operator_key#10014, matched_direction_key#10015, operator_key_match#11359, direction_key_match#11405, schedule_time_difference_seconds#11500]
# Arguments: [row_number() windowspecdefinition(observation_id#1268, operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS match_rank#11550], [observation_id#1268], [operator_key_match#11359 DESC NULLS LAST, direction_key_match#11405 DESC NULLS LAST, schedule_time_difference_seconds#11500 ASC NULLS LAST, matched_trip_id#10003 ASC NULLS LAST]
#
# (33) Filter
# Input [48]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268, matched_trip_id#10003, matched_service_id#10004, matched_route_id#10005, matched_route_short_name#10006, matched_vehicle_journey_code#10007, matched_direction_id#10008, matched_trip_headsign#10009, scheduled_start_seconds#212, scheduled_clock_seconds#429, scheduled_end_seconds#214, scheduled_stop_count#219L, matched_operator_key#10014, matched_direction_key#10015, operator_key_match#11359, direction_key_match#11405, schedule_time_difference_seconds#11500, match_rank#11550]
# Condition : (match_rank#11550 = 1)
#
# (34) Project
# Output [51]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268, matched_trip_id#10003, matched_service_id#10004, matched_route_id#10005, matched_route_short_name#10006, matched_vehicle_journey_code#10007, matched_direction_id#10008, matched_trip_headsign#10009, scheduled_start_seconds#212, scheduled_clock_seconds#429, scheduled_end_seconds#214, scheduled_stop_count#219L, matched_operator_key#10014, matched_direction_key#10015, operator_key_match#11359, direction_key_match#11405, schedule_time_difference_seconds#11500, CASE WHEN isnotnull(matched_trip_id#10003) THEN 1 ELSE 0 END AS is_timetable_matched#12949, CASE WHEN isnull(matched_trip_id#10003) THEN unmatched WHEN ((schedule_time_difference_seconds#11500 <= 900) AND (operator_key_match#11359 = 1)) THEN high WHEN (schedule_time_difference_seconds#11500 <= 1800) THEN medium WHEN isnull(schedule_time_difference_seconds#11500) THEN journey and line only ELSE low END AS match_quality#12998, line ref AS selected_line_method#13048, full journey reference AS selected_journey_method#13099]
# Input [48]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268, matched_trip_id#10003, matched_service_id#10004, matched_route_id#10005, matched_route_short_name#10006, matched_vehicle_journey_code#10007, matched_direction_id#10008, matched_trip_headsign#10009, scheduled_start_seconds#212, scheduled_clock_seconds#429, scheduled_end_seconds#214, scheduled_stop_count#219L, matched_operator_key#10014, matched_direction_key#10015, operator_key_match#11359, direction_key_match#11405, schedule_time_difference_seconds#11500, match_rank#11550]
#
# (35) Exchange
# Input [51]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268, matched_trip_id#10003, matched_service_id#10004, matched_route_id#10005, matched_route_short_name#10006, matched_vehicle_journey_code#10007, matched_direction_id#10008, matched_trip_headsign#10009, scheduled_start_seconds#212, scheduled_clock_seconds#429, scheduled_end_seconds#214, scheduled_stop_count#219L, matched_operator_key#10014, matched_direction_key#10015, operator_key_match#11359, direction_key_match#11405, schedule_time_difference_seconds#11500, is_timetable_matched#12949, match_quality#12998, selected_line_method#13048, selected_journey_method#13099]
# Arguments: hashpartitioning(line_ref#49, 4), REPARTITION_BY_NUM, [plan_id=5988]
#
# (36) AdaptiveSparkPlan
# Output [51]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268, matched_trip_id#10003, matched_service_id#10004, matched_route_id#10005, matched_route_short_name#10006, matched_vehicle_journey_code#10007, matched_direction_id#10008, matched_trip_headsign#10009, scheduled_start_seconds#212, scheduled_clock_seconds#429, scheduled_end_seconds#214, scheduled_stop_count#219L, matched_operator_key#10014, matched_direction_key#10015, operator_key_match#11359, direction_key_match#11405, schedule_time_difference_seconds#11500, is_timetable_matched#12949, match_quality#12998, selected_line_method#13048, selected_journey_method#13099]
# Arguments: isFinalPlan=false
#
# (37) TableCacheQueryStage
# Output [51]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268, matched_trip_id#10003, matched_service_id#10004, matched_route_id#10005, matched_route_short_name#10006, matched_vehicle_journey_code#10007, matched_direction_id#10008, matched_trip_headsign#10009, scheduled_start_seconds#10010, scheduled_clock_seconds#10011, scheduled_end_seconds#10012, scheduled_stop_count#10013L, matched_operator_key#10014, matched_direction_key#10015, operator_key_match#11359, direction_key_match#11405, schedule_time_difference_seconds#11500, is_timetable_matched#12949, match_quality#12998, selected_line_method#13048, selected_journey_method#13099]
# Arguments: 0
#
# (38) AdaptiveSparkPlan
# Output [51]: [source_file#44, snapshot_time#45, recorded_at_time#46, valid_until_time#47, operator_ref#48, line_ref#49, published_line_name#50, direction_ref#51, dated_vehicle_journey_ref#52, journey_pattern_ref#53, vehicle_ref#54, block_ref#55, origin_ref#56, destination_ref#57, destination_name#58, origin_aimed_departure_time#59, longitude#60, latitude#61, bearing#62, observation_date#63, observation_hour#64, observation_day_of_week#65, observation_age_seconds#66L, vehicle_operator_key#1072, vehicle_line_ref_key#1097, vehicle_published_line_key#1123, vehicle_journey_full_key#1150, vehicle_journey_tail_key#1178, vehicle_direction_key#1207, aimed_start_seconds#1237, observation_id#1268, matched_trip_id#10003, matched_service_id#10004, matched_route_id#10005, matched_route_short_name#10006, matched_vehicle_journey_code#10007, matched_direction_id#10008, matched_trip_headsign#10009, scheduled_start_seconds#10010, scheduled_clock_seconds#10011, scheduled_end_seconds#10012, scheduled_stop_count#10013L, matched_operator_key#10014, matched_direction_key#10015, operator_key_match#11359, direction_key_match#11405, schedule_time_difference_seconds#11500, is_timetable_matched#12949, match_quality#12998, selected_line_method#13048, selected_journey_method#13099]
# Arguments: isFinalPlan=true

# %%
# create the joined output folder when it does not exist
joined_path.mkdir(
    parents=True,
    exist_ok=True
)

print(
    "joined output folder:",
    joined_path
)
# Out:
# joined output folder: /Users/babitaadhikari/Desktop/bus-disruption-platform/data/processed/joined_transport_data

# %%
# save the joined transport dataset as parquet
(
    joined_df.write
    .mode("overwrite")
    .parquet(
        str(joined_path)
    )
)

print("joined transport data saved")
print("parquet location:", joined_path)
# Out:
# [Stage 240:>                                                        (0 + 4) / 4]
# joined transport data saved
# parquet location: /Users/babitaadhikari/Desktop/bus-disruption-platform/data/processed/joined_transport_data

# %%
# read the saved parquet dataset
saved_joined_df = spark.read.parquet(
    str(joined_path)
)

# count the saved rows
saved_joined_count = (
    saved_joined_df.count()
)

print(
    "original joined rows:",
    f"{joined_count:,}"
)

print(
    "saved joined rows:",
    f"{saved_joined_count:,}"
)

print(
    "saved partitions:",
    saved_joined_df.rdd.getNumPartitions()
)

# stop when the saved row count does not match
if saved_joined_count != joined_count:
    raise ValueError(
        "saved joined count does not match original count"
    )

print("joined parquet verification successful")
# Out:
# original joined rows: 9,546
# saved joined rows: 9,546
# saved partitions: 4
# joined parquet verification successful

# %%
# define the csv output folder
joined_csv_path = (
    project_root
    / "data"
    / "processed"
    / "joined_transport_data_csv"
)

# export the joined dataset as one csv part file
(
    saved_joined_df
    .coalesce(1)
    .write
    .mode("overwrite")
    .option(
        "header",
        True
    )
    .csv(
        str(joined_csv_path)
    )
)

print("joined csv dataset saved")
print("csv location:", joined_csv_path)
# Out:
# [Stage 245:>                                                        (0 + 1) / 1]
# joined csv dataset saved
# csv location: /Users/babitaadhikari/Desktop/bus-disruption-platform/data/processed/joined_transport_data_csv

# %%
# display the final dataset joining results
print("dataset joining summary")
print("-" * 50)

print(
    "trip level timetable rows:",
    f"{trip_level_df.count():,}"
)

print(
    "vehicle observations:",
    f"{original_vehicle_count:,}"
)

print(
    "matched observations:",
    f"{matched_vehicle_observations:,}"
)

print(
    "unmatched observations:",
    f"{unmatched_vehicle_observations:,}"
)

print(
    "join match rate:",
    f"{match_rate:.2f}%"
)

print(
    "selected line method:",
    selected_line_method
)

print(
    "selected journey method:",
    selected_journey_method
)

print(
    "final partitions:",
    joined_df.rdd.getNumPartitions()
)

print("main saved format: parquet")
print("parquet location:", joined_path)
print("csv location:", joined_csv_path)
# Out:
# dataset joining summary
# --------------------------------------------------
# [Stage 246:=================================================>       (7 + 1) / 8]
# trip level timetable rows: 135,003
# vehicle observations: 9,546
# matched observations: 17
# unmatched observations: 9,529
# join match rate: 0.18%
# selected line method: line ref
# selected journey method: full journey reference
# final partitions: 4
# main saved format: parquet
# parquet location: /Users/babitaadhikari/Desktop/bus-disruption-platform/data/processed/joined_transport_data
# csv location: /Users/babitaadhikari/Desktop/bus-disruption-platform/data/processed/joined_transport_data_csv
